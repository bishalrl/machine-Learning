# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("data/homeprices.csv")
canda=pd.read_csv("data/canada_per_capita_income.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline

plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg =linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
predicted_price = reg.predict([[3300]])
print(predicted_price)
# Out:
# [628715.75342466]
# d:\anocanda\ana\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y=m(coefficent)x+c(intercept)
y=135.78767123*3300+180616.43835616432
print(y)
# Out:
# 628715.7534151643

# %%
canda
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
canda.head(2)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935

# %%
plt.xlabel('year')
plt.ylabel('per_capital_income')
x = canda['year'].values  # Accessing the 'year' column
y = canda['per capita income (US$)']  # Accessing the 'per capita income (US$)' column
plt.scatter(x, y, color='blue', marker='+')
plt.plot(x, reg.predict(x), color='red') 
plt.show()
# Out:
# d:\anocanda\ana\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 6
#       4 y = canda['per capita income (US$)']  # Accessing the 'per capita income (US$)' column
#       5 plt.scatter(x, y, color='blue', marker='+')
# ----> 6 plt.plot(x, reg.predict(x), color='red')
#       7 plt.show()
#
# File d:\anocanda\ana\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# ...
